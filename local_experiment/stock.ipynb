# %%
#프로젝트의 루트 디렉토리를 설정하기 위한 코드
import os
current_dir = os.getcwd()  # 현재 작업 디렉토리
print(os.path.dirname(current_dir))
# print(os.path.dirname(os.path.dirname(current_dir)))
# 루트 경로 설정 (예: 프로젝트 루트 경로)
project_root = os.path.dirname(current_dir)
os.chdir(project_root)  # 루트 경로로 변경
# Out:
# c:\sb-fsts\sb-fsts

# %%
import datetime
import matplotlib.pyplot as plt
import mplfinance as mpf
import pandas as pd
import numpy as np
import requests

# %%
from app.utils.auto_trading_bot import AutoTradingBot
from pykis import KisBalance

auto_trading_stock = AutoTradingBot(id = 'bnuazz15bot_real', virtual= False)
trading_bot_name = 'bnuazz15bot_real'
# ✅ scheduled_trading 시작 시 잔고 조회
kis_account = auto_trading_stock.kis.account()
kis_balance: KisBalance = kis_account.balance()

non_zero_stocks = [stock for stock in kis_balance.stocks if stock.qty != 0]
kis_balance.stocks = non_zero_stocks
# Out:
# 실전투자 API 객체가 성공적으로 생성되었습니다.

# %%
# 주문 가능 금액 구하는 법 (우회)
# 매수가 1원으로 주문 가능 금액을 구함
from datetime import time
from pykis import KisOrderableAmount

max_retries = 5
kis_krw_balance = 0

for attempt in range(0, max_retries):
    try:
        orderable_amount: KisOrderableAmount = kis_account.orderable_amount(
            market="KRX",
            price=1,
            symbol="039200"
        )

        kis_krw_balance = int(orderable_amount.qty)
        break

    except Exception as e:
        print(f"[{attempt+1}/{max_retries}] 주문 가능 금액 조회 실패: {e}")
        time.sleep(1)  # 1초 대기 후 재시도

kis_krw_balance
# Out:
# 1366561

# %%
symbols = [stock.symbol for stock in kis_balance.stocks]
print(symbols)
# Out:
# ['006730', '036830', '085660', '117730', '237690', '241710', '376300']

# %%
from datetime import date
from pykis import KisOrderProfits

def get_total_profits_from(start_date: date):
    return account.profits(start=start_date, end=date.today())

profits = get_total_profits_from(date(2023, 8, 1))
print(repr(profits))
# Out:
# KisIntegrationOrderProfits(
#     account_number=KisAccountNumber('64156776-01'),
#     buy_amount=1353000,
#     sell_amount=1530350,
#     profit=177350,
#     orders=[
#         KisDomesticOrderProfit(time_kst='2025-04-17T00:00:00+09:00', market='KRX', symbol='042000', name='카페24', buy_price=54600, sell_price=59278, qty=9, profit=42100, profit_rate=8.567358567358567358567358567),
#         KisDomesticOrderProfit(time_kst='2025-04-16T00:00:00+09:00', market='KRX', symbol='298380', name='에이비엘바이오', buy_price=50700, sell_price=63706, qty=9, profit=117050, profit_rate=25.65198334429103659872890642),
#         KisDomesticOrderProfit(time_kst='2025-04-15T00:00:00+09:00', market='KRX', symbol='010620', name='HD현대미포', buy_price=115500, sell_price=132900, qty=1, profit=17400, profit_rate=15.06493506493506493506493506),
#         KisDomesticOrderProfit(time_kst='2025-04-15T00:00:00+09:00', market='KRX', symbol='010140', name='삼성중공업', buy_price=14490, sell_price=14530, qty=20, profit=800, profit_rate=0.2760524499654934437543133195)
#     ]
# )

# %%
from app.scheduler.auto_trading_scheduler import netbuy_summary_by_investor

netbuy_summary_by_investor(id='bnuazz15bot_real', virtual = False, trading_bot_name = 'bnuazz15bot_real')
# Out:
# 실전투자 API 객체가 성공적으로 생성되었습니다.
# 메시지가 성공적으로 전송되었습니다.
# 메시지가 성공적으로 전송되었습니다.
# 메시지가 성공적으로 전송되었습니다.
# 메시지가 성공적으로 전송되었습니다.
# 메시지가 성공적으로 전송되었습니다.
# 메시지가 성공적으로 전송되었습니다.
# 메시지가 성공적으로 전송되었습니다.
# 메시지가 성공적으로 전송되었습니다.

# %%
from app.utils.dynamodb.model.stock_symbol_model import StockSymbol 
    
result = list(StockSymbol.scan(
        filter_condition=((StockSymbol.type == 'kospi200'))
    )) #scan은 랜덤, 정렬 불가 -> 종목 순서 기준은 추후 검토
    
sorted_result = sorted(
        result,
        key=lambda x: (x.type, x.symbol_name)
    )

# %%
from app.utils.dynamodb.model.stock_symbol_model import StockSymbol 
# theme 리스트에 '2차전지'가 포함된 항목만
result = StockSymbol.scan(filter_condition=StockSymbol.theme.contains('사료'))

print(result)
# Out:
# <pynamodb.pagination.ResultIterator object at 0x0000025FC14F87C0>

# %%
sorted_result

# %%
#주문가능금액 API
import requests
from app.utils.auto_trading_bot import AutoTradingBot
import boto3

id = "bnuazz15bot_real"
symbol = '005930'
auto_trading_stock = AutoTradingBot(id=id, virtual=False)

print(auto_trading_stock.virtual_account)
print(auto_trading_stock.kis.token)
# Out:
# 실전투자 API 객체가 성공적으로 생성되었습니다.
# 50131636
# Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImUyOGU1MjBhLWZiNmQtNDcxYi05YjViLTM5MjM5YTlmYWM5MiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc1MTc3NDEzMSwiaWF0IjoxNzUxNjg3NzMxLCJqdGkiOiJQU1NUc1JQRXF3Rk9BcWl3MVdnT3NtcHNDVG9GMENUNDZZakoifQ.TNQgfH37BUqjZ8EPbJ35Tm4RlmCNLXe-GE9AcC4X2wdGt7bubXozvix76kHuQikaUIYRCh9TyCQdOf8TT2uo2Q

# %%
from datetime import date
symbol = '403870'
stock_name = '삼성전자'
stock_type = 'kospi200'
start_date = date(2024,1,1)
end_date = date(2024,2,15)
target_trade_value_krw = 100000
target_trade_value_ratio = 20
min_trade_value = 100
buy_trading_logic = ['trend_entry_trading']
sell_trading_logic = ['']
indicators = []
auto_trading_stock.simulate_trading(symbol, stock_name, stock_type, start_date, end_date, target_trade_value_krw, target_trade_value_ratio, min_trade_value, buy_trading_logic,sell_trading_logic, indicators = indicators)
# Out:
# 403870 삼성전자 kospi200 2024-01-01 2023-07-05 2024-02-15 100000
# ❗ 종가 NaN인 row 샘플:
# Empty DataFrame
# Columns: [Time, Open, High, Low, Close, Volume, 종가, 전일대비, 전일대비부호, 전일대비율, 누적거래량, 기준거래량합계, 공매도체결수량, 공매도거래량비중, 누적공매도체결수량, 누적공매도수량비중, 누적거래대금, 기준거래대금합계, 공매도거래대금, 공매도거래대금비중, 누적공매도거래대금, 누적공매도거래대금비중, 시가, 고가, 저가, 공매도평균가격, EMA_5, EMA_10, EMA_13, EMA_20, EMA_21, EMA_55, EMA_60, EMA_89, EMA_120, SMA_5, SMA_10, SMA_20, SMA_40, SMA_60, SMA_120, SMA_200, rsi, ema_short, ema_long, macd, macd_signal, macd_histogram, stochastic_k, stochastic_d, TP, RMF, Prev_TP, Positive_MF, Negative_MF, PMF, NMF, MFR, mfi, BB_Middle, BB_Upper, BB_Lower, horizontal_high, horizontal_low, EMA_89_Slope, EMA_55_Slope, EMA_55_Slope_MA, EMA_89_Slope_MA]
# Index: []
#
# [0 rows x 68 columns]
#  df2:                                 Time     Open     High      Low    Close  \
# 2023-07-05 2023-07-05 00:00:00+09:00  29050.0  29100.0  27700.0  27800.0
# 2023-07-06 2023-07-06 00:00:00+09:00  27400.0  28200.0  27000.0  27250.0
# 2023-07-07 2023-07-07 00:00:00+09:00  27250.0  27500.0  26600.0  27350.0
# 2023-07-10 2023-07-10 00:00:00+09:00  27350.0  27500.0  26200.0  26950.0
# 2023-07-11 2023-07-11 00:00:00+09:00  27100.0  27450.0  26650.0  27200.0
# ...                              ...      ...      ...      ...      ...
# 2024-02-07 2024-02-07 00:00:00+09:00  45650.0  46150.0  43800.0  44000.0
# 2024-02-08 2024-02-08 00:00:00+09:00  44500.0  48950.0  44100.0  48950.0
# 2024-02-13 2024-02-13 00:00:00+09:00  49400.0  62400.0  49250.0  59300.0
# 2024-02-14 2024-02-14 00:00:00+09:00  57500.0  63200.0  56100.0  61600.0
# 2024-02-15 2024-02-15 00:00:00+09:00  62400.0  63900.0  59200.0  63100.0
#
#                 Volume     종가   전일대비  전일대비부호  전일대비율  ...    mfi  BB_Middle  \
# 2023-07-05   1135330.0  27800  -1150       5  -3.97  ...    NaN        NaN
# 2023-07-06   1036985.0  27250   -550       5  -1.98  ...    NaN        NaN
# 2023-07-07    990045.0  27350    100       2   0.37  ...    NaN        NaN
# 2023-07-10   1149545.0  26950   -400       5  -1.46  ...    NaN        NaN
# 2023-07-11    616987.0  27200    250       2   0.93  ...    NaN        NaN
# ...                ...    ...    ...     ...    ...  ...    ...        ...
# 2024-02-07   1289026.0  44000  -2150       5  -4.66  ...  65.90    45560.0
# 2024-02-08   4355863.0  48950   4950       2  11.25  ...  65.47    45887.5
# 2024-02-13  15671806.0  59300  10350       2  21.14  ...  76.30    46762.5
# 2024-02-14   8284076.0  61600   2300       2   3.88  ...  77.21    47782.5
# 2024-02-15   5172122.0  63100   1500       2   2.44  ...  83.61    48850.0
#
#                 BB_Upper      BB_Lower  horizontal_high  horizontal_low  \
# 2023-07-05           NaN           NaN             None            None
# 2023-07-06           NaN           NaN             None            None
# 2023-07-07           NaN           NaN             None            None
# 2023-07-10           NaN           NaN             None            None
# 2023-07-11           NaN           NaN             None            None
# ...                  ...           ...              ...             ...
# 2024-02-07  50998.529213  40121.470787             None            None
# 2024-02-08  51314.273904  40460.726096             None            None
# 2024-02-13  54445.264802  39079.735198             None            None
# 2024-02-14  57410.857856  38154.142144             None            None
# 2024-02-15  60154.600833  37545.399167             None            None
#
#             EMA_89_Slope  EMA_55_Slope  EMA_55_Slope_MA  EMA_89_Slope_MA
# 2023-07-05           NaN           NaN              NaN              NaN
# 2023-07-06        -278.0     -1.007194              NaN              NaN
# 2023-07-07         -59.0     -0.214390              NaN              NaN
# 2023-07-10        -132.0     -0.491606        -0.571063      -156.333333
# 2023-07-11         -28.0     -0.098807        -0.268268       -73.000000
# ...                  ...           ...              ...              ...
# 2024-02-07          49.0      0.032101         0.157162        83.666667
# 2024-02-08         161.0      0.437802         0.229401       103.666667
# 2024-02-13         396.0      1.266603         0.578835       202.000000
# 2024-02-14         440.0      1.392739         1.032381       332.333333
# 2024-02-15         463.0      1.442511         1.367284       433.000000
#
# [151 rows x 68 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 13
#      11 sell_trading_logic = ['']
#      12 indicators = []
# ---> 13 auto_trading_stock.simulate_trading(symbol, stock_name, stock_type, start_date, end_date, target_trade_value_krw, target_trade_value_ratio, min_trade_value, buy_trading_logic,sell_trading_logic, indicators = indicators)
#
# File c:\sb-fsts\sb-fsts\app\utils\auto_trading_bot.py:270, in AutoTradingBot.simulate_trading(self, symbol, stock_name, stock_type, start_date, end_date, target_trade_value_krw, target_trade_value_ratio, min_trade_value, buy_trading_logic, sell_trading_logic, interval, buy_percentage, ohlc_mode, initial_capital, rsi_period, take_profit_logic, stop_loss_logic, indicators)
#     267     return None, None, None
#     269 # 익절, 손절 로직 별 다양화
# --> 270 if take_profit_logic['name'] is None:
#     271     use_take_profit = False
#     272     take_profit_ratio = 0
#
# TypeError: 'NoneType' object is not subscriptable

# %%
symbol = '085660'
response = auto_trading_stock.get_investor_trend_estimate(symbol)
response
# Out:
# {'output2': [], 'rt_cd': '0', 'msg_cd': 'MCA00000', 'msg1': '정상처리 되었습니다.'}

# %%
close_price = 303000
auto_trading_stock.calculate_trade_value_from_fake_qty(response, close_price, symbol)
# Out:
# -26967000000

# %%
from datetime import date, datetime
import requests
from app.utils.auto_trading_bot import AutoTradingBot

id = "bnuazz15bot_real"
symbol = '229200'
auto_trading_stock = AutoTradingBot(id=id, virtual=False)

data_start_date = date(2023, 3, 1)
end_date = date(2025, 4, 3)
interval = 'day'
ohlc_mode = 'default'

ohlc_data = auto_trading_stock._get_ohlc(symbol, data_start_date, end_date, interval, ohlc_mode)
# Out:
# 실전투자 API 객체가 성공적으로 생성되었습니다.

# %%
ohlc_data

# %%
symbol = '376300'
start_date = '20250701'
end_date = '20250708'
market_code = 'J'
auto_trading_stock.get_short_sale_daily_trend(symbol = symbol,start_date=start_date,end_date=end_date, market_code=market_code )

# %%
from app.utils.dynamodb.model.user_info_model import UserInfo
from app.utils.dynamodb.model.auto_trading_balance_model import AutoTradingBalance
from app.utils.dynamodb.model.stock_symbol_model import StockSymbol

# ✅ 코스닥150 종목 가져오기
result = list(StockSymbol.scan(
    filter_condition=(StockSymbol.type == 'kosdaq150')
))

result
# Out:
# [StockSymbol(created_at=1745301561544, industry='일반서비스', symbol='358570', symbol_name='지아이이노베이션', theme={'항암바이오신약'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301588718, industry='의료정밀기기', symbol='131290', symbol_name='티에스이', theme={'OLED장비', '반도체 후공정 장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301571979, industry='일반서비스', symbol='036830', symbol_name='솔브레인홀딩스', theme={'지주사', '진단기기', 'OLED부품소재', '배터리소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301542856, industry='화학', symbol='357780', symbol_name='솔브레인', theme={'반도체 전공정 소재', 'LCD부품소재', '배터리소재', 'OLED부품소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301532106, industry='오락문화', symbol='035900', symbol_name='JYP Ent.', theme={'연예기획사'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301602379, industry='화학', symbol='114840', symbol_name='아이패밀리에스씨', theme={'화잠품브랜드'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301535540, industry='유통', symbol='257720', symbol_name='실리콘투', theme={'온라인쇼핑'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301529956, industry='제약', symbol='000250', symbol_name='삼천당제약', theme={'전문의약품', '일반의약품'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301540653, industry='화학', symbol='005290', symbol_name='동진쎄미켐', theme={'정밀화학', 'LCD부품소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301571359, industry='금융', symbol='003380', symbol_name='하림지주', theme={'지주사'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301550654, industry='오락문화', symbol='122870', symbol_name='와이지엔터테인먼트', theme={'연예기획사'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301610803, industry='화학', symbol='352480', symbol_name='씨앤씨인터내셔널', theme={'화장품제조'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301595266, industry='IT서비스', symbol='069080', symbol_name='웹젠', theme={'게임개발', '게임플랫폼'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301544808, industry='제약', symbol='214370', symbol_name='케어젠', theme={'보톡스와 필러', '화장품제조'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301600076, industry='일반서비스', symbol='006730', symbol_name='서부T&D', theme={'호텔과 리조트', '유통'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301576510, industry='기계장비', symbol='348210', symbol_name='넥스틴', theme={'반도체 전공정 장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301578862, industry='IT서비스', symbol='030520', symbol_name='한글과컴퓨터', theme={'광고', '소프트웨어'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301527878, industry='제약', symbol='087010', symbol_name='펩트론', theme={'치매바이오신약', '항암바이오신약', '전문의약품'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301613156, industry='IT서비스', symbol='394280', symbol_name='오픈엣지테크놀로지', theme={'반도체'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301617115, industry='화학', symbol='095500', symbol_name='미래나노텍', theme={'LCD부품소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301536229, industry='기계장비', symbol='403870', symbol_name='HPSP', theme={'반도체 전공정 장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301538424, industry='화학', symbol='348370', symbol_name='엔켐', theme={'배터리소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301554407, industry='IT서비스', symbol='293490', symbol_name='카카오게임즈', theme={'게임개발', '골프', '게임플랫폼'}, type='kosdaq150'),
#  StockSymbol(created_at=1751956606546, industry='기계장비', symbol='161580', symbol_name='필옵틱스', theme={'OLED장비', '배터리장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301598251, industry='전기전자', symbol='091700', symbol_name='파트론', theme={'스마트폰카메라'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301559965, industry='IT서비스', symbol='067160', symbol_name='SOOP', theme={'동영상플랫폼'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301525359, industry='기계장비', symbol='277810', symbol_name='레인보우로보틱스', theme={'로봇'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301597665, industry='제약', symbol='064550', symbol_name='바이오니아', theme={'건강기능식품', '진단기기', '바이오서비스'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301563898, industry='기계장비', symbol='232140', symbol_name='와이씨', theme={'반도체 후공정 장비', '반도체 후공정 소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301539075, industry='IT서비스', symbol='328130', symbol_name='루닛', theme={'영산진단기기', '인공지능'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301528663, industry='제약', symbol='214450', symbol_name='파마리서치', theme={'화장품브랜드', '보톡스와 필러', '전문의약품'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301609622, industry='전기전자', symbol='032500', symbol_name='케이엠더블유', theme={'무선장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301591088, industry='전기전자', symbol='272290', symbol_name='이녹스첨단소재', theme={'OLED부품소재', '스마트폰FPCB'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301562136, industry='화학', symbol='281740', symbol_name='레이크머티리얼즈', theme={'반도체 전공정 소재', '태양광에너지', 'LED'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301601353, industry='화학', symbol='365340', symbol_name='성일하이텍', theme={'퍠배터리재활용'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301602962, industry='전기전자', symbol='218410', symbol_name='RFHIC', theme={'방위산업물자', '무선장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301553649, industry='기계장비', symbol='089030', symbol_name='테크윙', theme={'OLED장비', '반도체 후공정 장비', 'LCD장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301565066, industry='전기전자', symbol='101490', symbol_name='에스앤에스텍', theme={'반도체 전공정 소재', 'LCD부품소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1751956532146, industry='일반서비스', symbol='034950', symbol_name='한국기업평가', theme={'신용평가'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301592895, industry='유통', symbol='032190', symbol_name='다우데이타', theme={'보안', '소프트웨어', '금융그룹'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301594656, industry='전기전자', symbol='080220', symbol_name='제주반도체', theme={'반도체팹리스'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301534263, industry='제약', symbol='068760', symbol_name='셀트리온제약', theme={'바이오시밀러', '전문의약품'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301537764, industry='기계장비', symbol='036930', symbol_name='주성엔지니어링', theme={'반도체 전공정 장비', 'OLED장비', 'LCD장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301592252, industry='운송장비부품', symbol='015750', symbol_name='성우하이텍', theme={'자동차차체'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301531408, industry='오락문화', symbol='041510', symbol_name='에스엠', theme={'광고', '연예기획사'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301610209, industry='기계장비', symbol='420770', symbol_name='기가비스', theme={'반도체 후공정 장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1751956512364, industry='금속', symbol='014620', symbol_name='성광벤드', theme={'플랜트기자재', '조선기자재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301605421, industry='전기전자', symbol='179900', symbol_name='유티아이', theme={'스마트폰카메라'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301606065, industry='IT서비스', symbol='108860', symbol_name='셀바스AI', theme={'인공지능'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301574710, industry='IT서비스', symbol='058970', symbol_name='엠로', theme={'IT솔루션구축'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301604230, industry='전기전자', symbol='094360', symbol_name='칩스앤미디어', theme={'반도체팹리스'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301584204, industry='일반서비스', symbol='215200', symbol_name='메가스터디교육', theme={'초중고학원', '성인교육학원'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301555680, industry='기계장비', symbol='240810', symbol_name='원익IPS', theme={'반도체 전공정 장비', 'OLED장비', 'LCD장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301570115, industry='제약', symbol='086450', symbol_name='동국제약', theme={'건강기능식품', '전문의약품', '일반의약품'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301598855, industry='기계장비', symbol='253590', symbol_name='네오셈', theme={'반도체 후공정 장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301606666, industry='유통', symbol='060280', symbol_name='큐렉소', theme={'무역', '치과의료기기'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301532923, industry='IT서비스', symbol='263750', symbol_name='펄어비스', theme={'게임개발', '게임플랫폼'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301526087, industry='제약', symbol='145020', symbol_name='휴젤', theme={'화장품브랜드', '보톡스와 필러'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301583031, industry='금속', symbol='009520', symbol_name='포스코엠텍', theme={'철강'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301564485, industry='IT서비스', symbol='053800', symbol_name='안랩', theme={'보안'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301557507, industry='IT서비스', symbol='376300', symbol_name='디어유', theme={'연예기획사'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301566272, industry='기계장비', symbol='031980', symbol_name='피에스케이홀딩스', theme={'반도체 후공정 장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301523031, industry='일반서비스', symbol='196170', symbol_name='알테오젠', theme={'바이오시밀러', '항암바이오신약'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301560952, industry='기계장비', symbol='098460', symbol_name='고영', theme={'반도체 후공정 장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301543590, industry='IT서비스', symbol='042000', symbol_name='카페24', theme={'쇼핑몰구축'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301534911, industry='일반서비스', symbol='310210', symbol_name='보로노이', theme={'항암바이오신약'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301565662, industry='기계장비', symbol='084370', symbol_name='유진테크', theme={'반도체 전공정 소재', '반도체 전공정 장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1751956627833, industry='IT서비스', symbol='101730', symbol_name='위메이드맥스', theme={'게임개발'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301558148, industry='IT서비스', symbol='112040', symbol_name='위메이드', theme={'게임개발', '게임플랫폼'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301577658, industry='화학', symbol='383310', symbol_name='에코프로에이치엔', theme={'탄소저감'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301600712, industry='전기전자', symbol='036810', symbol_name='에프에스티', theme={'반도체 전공정 소재', 'LCD부품소재', '반도체 전공정 장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301593476, industry='의료정밀기기', symbol='099190', symbol_name='아이센스', theme={'진단기기'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301572558, industry='기계장비', symbol='183300', symbol_name='코미코', theme={'반도체 전공정 장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301578292, industry='기계장비', symbol='222080', symbol_name='씨아이에스', theme={'배터리장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301555075, industry='전기전자', symbol='178320', symbol_name='서진시스템', theme={'반도체 전공정 소재', 'ESS', '무선장비', '배터리부품'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301597063, industry='기계장비', symbol='095610', symbol_name='테스', theme={'반도체 전공정 장비', 'OLED장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301575289, industry='일반서비스', symbol='025980', symbol_name='아난티', theme={'호텔과 리조트'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301580649, industry='기계장비', symbol='319660', symbol_name='피에스케이', theme={'반도체 전공정 장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301573717, industry='화학', symbol='121600', symbol_name='나노신소재', theme={'배터리소재', '디스플레이부품소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301527299, industry='의료정밀기기', symbol='214150', symbol_name='클래시스', theme={'미용의료기기'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301524784, industry='금융', symbol='086520', symbol_name='에코프로', theme={'지주사', '배터리소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1751956486322, industry='화학', symbol='033500', symbol_name='동성화인텍', theme={'조선기자재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301590500, industry='화학', symbol='317330', symbol_name='덕산테코피아', theme={'반도체 전공정 소재', 'OLED부품소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301558746, industry='기계장비', symbol='137400', symbol_name='피엔티', theme={'배터리장비', '산업용 기계'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301582426, industry='제약', symbol='053030', symbol_name='바이넥스', theme={'CMO', '전문의약품'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301529271, industry='제약', symbol='298380', symbol_name='에이비엘바이오', theme={'항암바이오신약'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301583616, industry='화학', symbol='241710', symbol_name='코스메카코리아', theme={'화장품제조'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301584813, industry='IT서비스', symbol='095660', symbol_name='네오위즈', theme={'게임개발', '게임플랫폼'}, type='kosdaq150'),
#  StockSymbol(created_at=1751956571816, industry='기계장비', symbol='079370', symbol_name='제우스', theme={'반도체 전공정 장비', '로봇'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301587152, industry='전기전자', symbol='399720', symbol_name='가온칩스', theme={'반도체'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301542187, industry='의료정밀기기', symbol='140860', symbol_name='파크시스템스', theme={'반도체 전공정 장비', '디스플레이장비', '의료기기'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301539850, industry='제약', symbol='237690', symbol_name='에스티팜', theme={'제약', 'CMO'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301580052, industry='화학', symbol='048410', symbol_name='현대바이오', theme={'화장품제조'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301613722, industry='전기전자', symbol='049070', symbol_name='인탑스', theme={'스마트폰액세서리', '자동차차체'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301581218, industry='전기전자', symbol='166090', symbol_name='하나머티리얼즈', theme={'반도체 전공정 소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1751956706662, industry='전기전자', symbol='050890', symbol_name='쏠리드', theme={'무선장비', '유선장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301567653, industry='전기전자', symbol='067310', symbol_name='하나마이크론', theme={'반도체패키징'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301581843, industry='전기전자', symbol='222800', symbol_name='심텍', theme={'반도체 후공정 소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301568931, industry='전기전자', symbol='213420', symbol_name='덕산네오룩스', theme={'OLED부품소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301566918, industry='의료정밀기기', symbol='336570', symbol_name='원텍', theme={'미용의료기기'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301591684, industry='IT서비스', symbol='194480', symbol_name='데브시스터즈', theme={'게임개발', '게임플랫폼'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301533584, industry='제약', symbol='007390', symbol_name='네이처셀', theme={'건강기능식품', '음료', '줄기세포바이오신'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301530703, industry='전기전자', symbol='058470', symbol_name='리노공업', theme={'반도체 후공정 소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301595860, industry='종이목재', symbol='025900', symbol_name='동화기업', theme={'목재', '마루', '배터리소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301577099, industry='전기전자', symbol='058610', symbol_name='에스피지', theme={'전자부품'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301599455, industry='IT서비스', symbol='215000', symbol_name='골프존', theme={'골프'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301607251, industry='화학', symbol='278280', symbol_name='천보', theme={'반도체 전공정 소재', 'LCD부품소재', '배터리소재', 'OLED부품소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301579468, industry='금융', symbol='041190', symbol_name='우리기술투자', theme={'밴처캐피탈'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301556938, industry='유통', symbol='095340', symbol_name='ISC', theme={'반도체 후공정 장비', '반도체 후공정 소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301617662, industry='전기전자', symbol='084850', symbol_name='아이티엠반도체', theme={'배터리부품', '반도체'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301607855, industry='기계장비', symbol='171090', symbol_name='선익시스템', theme={'OLED장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301552921, industry='제약', symbol='039200', symbol_name='오스코텍', theme={'식자재유통', '바이오신약', '치과의료기기'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301569542, industry='전기전자', symbol='417200', symbol_name='LS머트리얼즈', theme={'ESS', '알루미늄'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301573134, industry='제약', symbol='085660', symbol_name='차바이오텍', theme={'줄기세포바이오신약', '화장품제조'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301588140, industry='제약', symbol='290650', symbol_name='엘앤씨바이오', theme={'의료기기'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301547497, industry='화학', symbol='018290', symbol_name='브이티', theme={'화장품브랜드', '정밀화학', '산업용 기계'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301596463, industry='전기전자', symbol='189300', symbol_name='인텔리안테크', theme={'방위산업물자', '무선장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301575922, industry='전기전자', symbol='025320', symbol_name='시노펙스', theme={'스마트폰FPCB'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301526640, industry='일반서비스', symbol='141080', symbol_name='리가켐바이오', theme={'바이오신약', '의료기기'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301563329, industry='전기전자', symbol='204270', symbol_name='제이앤티씨', theme={'스마트폰화면', '스마트폰부품'}, type='kosdaq150'),
#  StockSymbol(created_at=1751956650933, industry='전기전자', symbol='160190', symbol_name='하이젠알앤엠', theme={'로봇', '산업용 기계'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301541399, industry='기계장비', symbol='039030', symbol_name='이오테크닉스', theme={'OLED 장비', '반도체 후공정 장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301552043, industry='일반서비스', symbol='140410', symbol_name='메지온', theme={'사료'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301604838, industry='제약', symbol='200130', symbol_name='콜마비앤에이치', theme={'건강기능식품', '화장품제조'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301568310, industry='기계장비', symbol='056190', symbol_name='에스에프에이', theme={'반도체 전공정 장비', 'OLED장비', '반도체 후공정 장비', 'LCD장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301545725, industry='기계장비', symbol='082270', symbol_name='젬백스', theme={'치매바이오신약', '플랜트기자재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301589888, industry='일반서비스', symbol='131970', symbol_name='두산테스나', theme={'반도체패키징'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301615937, industry='기계장비', symbol='053610', symbol_name='프로텍', theme={'반도체 후공정 장비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301546585, industry='제약', symbol='096530', symbol_name='씨젠', theme={'진단기기'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301548421, industry='오락문화', symbol='253450', symbol_name='스튜디오드래곤', theme={'방송콘텐츠제작'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301594075, industry='비금속', symbol='074600', symbol_name='원익QnC', theme={'반도체 전공정 소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301562708, industry='IT서비스', symbol='225570', symbol_name='넥슨게임즈', theme={'게임개발'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301585402, industry='전기전자', symbol='033100', symbol_name='제룡전기', theme={'전기설비'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301559364, industry='비금속', symbol='064760', symbol_name='티씨케이', theme={'반도체 전공정 소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301611981, industry='음식료담배', symbol='267980', symbol_name='매일유업', theme={'과자', '커피', '우유'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301537003, industry='전기전자', symbol='065350', symbol_name='신성델타테크', theme={'배터리부품', '생활용품', '자동차공조시스템', '가전부품'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301549960, industry='전기전자', symbol='078600', symbol_name='대주전자재료', theme={'전자부품', '태양광에너지', '배터리소재', '디스플레이부품소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301551280, industry='제약', symbol='086900', symbol_name='메디톡스', theme={'보톡스와 필러'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301556315, industry='제약', symbol='195940', symbol_name='HK이노엔', theme={'제약', '음료'}, type='kosdaq150'),
#  StockSymbol(created_at=1751956551215, industry='기계장비', symbol='323280', symbol_name='태성', theme={'산업용 기계'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301524207, industry='제약', symbol='028300', symbol_name='HLB', theme={'항암바이오신약', '조선기자재', '의료기기'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301586565, industry='IT서비스', symbol='078340', symbol_name='컴투스', theme={'게임개발', '게임플랫폼'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301570723, industry='유통', symbol='115450', symbol_name='HLB테라퓨틱스', theme={'전문의약품', '전자부품'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301611391, industry='금융', symbol='060250', symbol_name='NHN KCP', theme={'결제서비스'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301589307, industry='화학', symbol='101360', symbol_name='에코앤드림', theme={'농업용 기계', '탄소저감', '자동차부품'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301618289, industry='전기전자', symbol='091120', symbol_name='이엠텍', theme={'생활가전', '담배', '스마트폰부품'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301523650, industry='전기전자', symbol='247540', symbol_name='에코프로비엠', theme={'배터리소재'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301603644, industry='전기전자', symbol='046890', symbol_name='서울반도체', theme={'LED'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301585969, industry='전기전자', symbol='036540', symbol_name='SFA반도체', theme={'반도체패키징'}, type='kosdaq150'),
#  StockSymbol(created_at=1745301549191, industry='오락문화', symbol='035760', symbol_name='CJ ENM', theme={'유료방송', '영화제작', '온라인쇼핑', '홈쇼핑'}, type='kosdaq150')]

# %%
from app.utils.dynamodb.model.auto_trading_balance_model import AutoTradingBalance
from app.utils.dynamodb.model.user_info_model import UserInfo
print("현재 리전:", AutoTradingBalance.Meta.region)
print("현재 테이블명:", AutoTradingBalance.Meta.table_name)

try:
    exists = AutoTradingBalance.exists()
    print(f"테이블 존재 여부: {exists}")
except Exception as e:
    print("테이블 존재 확인 중 에러 발생:", e)
    
print("현재 리전:", UserInfo.Meta.region)
print("현재 테이블명:", UserInfo.Meta.table_name)

try:
    exists = UserInfo.exists()
    print(f"테이블 존재 여부: {exists}")
except Exception as e:
    print("테이블 존재 확인 중 에러 발생:", e)
# Out:
# ✅  .env 파일 로드 성공: c:\sb-fsts\sb-fsts\.env
# 현재 리전: ap-northeast-2
# 현재 테이블명: fsts-auto-trading-balance
# 테이블 존재 여부: False
# 현재 리전: ap-northeast-2
# 현재 테이블명: fsts-user-info
# 테이블 존재 여부: False
